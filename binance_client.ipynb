# %%
from configparser import ConfigParser
from binance.client import Client
from binance.enums import *

# %%
CREDENTIALS_PATH = os.path.join(os.path.expanduser('~'), ".binance/credentials")
CREDENTIALS_PATH
# Out:
# 'C:\\Users\\Marcos Augusto\\.binance/credentials'

# %%
config = ConfigParser()
config.read(CREDENTIALS_PATH)
api_key = config.get('trade', 'API_KEY')
api_secret  = config.get('trade', 'SECRET_KEY')

# %%
binance_client = Client(api_key=api_key, api_secret=api_secret)

# %%
order = binance_client.create_test_order(
    symbol='DOTUSDT',
    side=SIDE_BUY,
    type=ORDER_TYPE_LIMIT,
    timeInForce=TIME_IN_FORCE_GTC,
    quantity=0.6,
    price='18')

# %%
order = binance_client.create_test_order(
    symbol='BTCUSDT',
    side=SIDE_BUY,
    type=ORDER_TYPE_LIMIT,
    timeInForce=TIME_IN_FORCE_GTC,
    quantity=0.000280,
    price='39000')

# %%
order = binance_client.order_market_buy(
    symbol='BTCUSDT',
    quantity=100)

# %%
order = binance_client.order_limit_buy(
    symbol='BTCUSDT',
    quantity=0.000280,
    price='39000')

# %%
order
# Out:
# {'symbol': 'BTCUSDT',
#  'orderId': 10271756038,
#  'orderListId': -1,
#  'clientOrderId': 'R52tY3TPXid1sL283l3YX0',
#  'transactTime': 1650647887764,
#  'price': '39000.00000000',
#  'origQty': '0.00028000',
#  'executedQty': '0.00000000',
#  'cummulativeQuoteQty': '0.00000000',
#  'status': 'NEW',
#  'timeInForce': 'GTC',
#  'type': 'LIMIT',
#  'side': 'BUY',
#  'fills': []}

# %%
binance_client.get_order(symbol='BTCUSDT', orderId='10271756038')
# Out:
# {'symbol': 'BTCUSDT',
#  'orderId': 10271756038,
#  'orderListId': -1,
#  'clientOrderId': 'R52tY3TPXid1sL283l3YX0',
#  'price': '39000.00000000',
#  'origQty': '0.00028000',
#  'executedQty': '0.00000000',
#  'cummulativeQuoteQty': '0.00000000',
#  'status': 'NEW',
#  'timeInForce': 'GTC',
#  'type': 'LIMIT',
#  'side': 'BUY',
#  'stopPrice': '0.00000000',
#  'icebergQty': '0.00000000',
#  'time': 1650647887764,
#  'updateTime': 1650647887764,
#  'isWorking': True,
#  'origQuoteOrderQty': '0.00000000'}

# %%
result = binance_client.cancel_order(symbol='BTCUSDT', orderId='10271756038')

# %%
binance_client.get_exchange_info()
# Out:
# {'timezone': 'UTC',
#  'serverTime': 1650642915310,
#  'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT',
#    'interval': 'MINUTE',
#    'intervalNum': 1,
#    'limit': 1200},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'SECOND',
#    'intervalNum': 10,
#    'limit': 50},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'DAY',
#    'intervalNum': 1,
#    'limit': 160000},
#   {'rateLimitType': 'RAW_REQUESTS',
#    'interval': 'MINUTE',
#    'intervalNum': 5,
#    'limit': 6100}],
#  'exchangeFilters': [],
#  'symbols': [{'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
# ...

# %%
binance_client.get_all_tickers()
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.07479900'},
#  {'symbol': 'LTCBTC', 'price': '0.00269800'},
#  {'symbol': 'BNBBTC', 'price': '0.01028900'},
#  {'symbol': 'NEOBTC', 'price': '0.00052900'},
#  {'symbol': 'QTUMETH', 'price': '0.00221800'},
#  {'symbol': 'EOSETH', 'price': '0.00084000'},
#  {'symbol': 'SNTETH', 'price': '0.00002140'},
#  {'symbol': 'BNTETH', 'price': '0.00075100'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00012410'},
#  {'symbol': 'BNBETH', 'price': '0.13760000'},
#  {'symbol': 'BTCUSDT', 'price': '39530.87000000'},
#  {'symbol': 'ETHUSDT', 'price': '2956.78000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00001076'},
# ...

# %%
binance_client.get_all_orders(symbol="BTCBRL")
# Out:
# [{'symbol': 'BTCBRL',
#   'orderId': 72276536,
#   'orderListId': -1,
#   'clientOrderId': 'web_b642367dbcc1454aa39f687f409468d3',
#   'price': '270384.00000000',
#   'origQty': '0.00029600',
#   'executedQty': '0.00029600',
#   'cummulativeQuoteQty': '79.98719200',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1621014600604,
#   'updateTime': 1621014600604,
#   'isWorking': True,
#   'origQuoteOrderQty': '0.00000000'},
#  {'symbol': 'BTCBRL',
#   'orderId': 88925729,
#   'orderListId': -1,
#   'clientOrderId': 'web_b0d0d641bf3a4af8a51516f7d6970de5',
#   'price': '188460.00000000',
#   'origQty': '0.00053000',
#   'executedQty': '0.00053000',
#   'cummulativeQuoteQty': '99.63456400',
#   'status': 'FILLED',
#   'timeInForce': 'GTC',
#   'type': 'LIMIT',
#   'side': 'BUY',
#   'stopPrice': '0.00000000',
#   'icebergQty': '0.00000000',
#   'time': 1622814681743,
# ...

# %%
binance_client.get_open_orders(symbol='BTCBRL')
# Out:
# []

# %%
binance_client.get_asset_balance(asset='ADA')
# Out:
# {'asset': 'ADA', 'free': '0.03203216', 'locked': '0.00000000'}

# %%
binance_client.get_trade_fee()
# Out:
# [{'symbol': '1INCHBTC',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': '1INCHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': '1INCHDOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': '1INCHUPUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': '1INCHUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AAVEBKRW',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
#  {'symbol': 'AAVEBNB', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEBRL', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEBTC', 'makerCommission': '0.001', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEDOWNUSDT',
#   'makerCommission': '0.001',
#   'takerCommission': '0.001'},
# ...
